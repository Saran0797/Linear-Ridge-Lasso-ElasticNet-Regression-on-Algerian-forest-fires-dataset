# %%
#importing all the necessary libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv('Algerian_forest_fires_dataset_UPDATE.csv', skiprows=1)
data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC  DMC    DC  ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7  3.4   7.6  1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4  4.1   7.6    1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1  2.5   7.1  0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6  1.3   6.9    0   1.7
# 4    05    06  2012          27  77  16     0  64.8    3  14.2  1.2   3.9
# ..   ..   ...   ...         ...  ..  ..   ...   ...  ...   ...  ...   ...
# 241  26    09  2012          30  65  14     0  85.4   16  44.5  4.5  16.9
# 242  27    09  2012          28  87  15   4.4  41.1  6.5     8  0.1   6.2
# 243  28    09  2012          27  87  29   0.5  45.9  3.5   7.9  0.4   3.4
# 244  29    09  2012          24  54  18   0.1  79.7  4.3  15.2  1.7   5.1
# 245  30    09  2012          24  64  15   0.2  67.3  3.8  16.5  1.2   4.8
#
#      FWI     Classes
# 0    0.5   not fire
# 1    0.4   not fire
# ...

# %%
data.shape
# Out:
# (246, 14)

# %%
pd.set_option('display.max_rows', 246)
data
# Out:
#                                day  month  year  Temperature   RH   Ws  Rain   \
# 0                               01     06  2012           29   57   18      0
# 1                               02     06  2012           29   61   13    1.3
# 2                               03     06  2012           26   82   22   13.1
# 3                               04     06  2012           25   89   13    2.5
# 4                               05     06  2012           27   77   16      0
# 5                               06     06  2012           31   67   14      0
# 6                               07     06  2012           33   54   13      0
# 7                               08     06  2012           30   73   15      0
# 8                               09     06  2012           25   88   13    0.2
# 9                               10     06  2012           28   79   12      0
# 10                              11     06  2012           31   65   14      0
# ...

# %%
data.drop(index=[122,123], inplace=True)

# %%
data
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7   3.4     7.6   1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4   4.1     7.6     1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1   2.5     7.1   0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6   1.3     6.9     0   1.7
# 4    05    06  2012          27  77  16     0  64.8     3    14.2   1.2   3.9
# 5    06    06  2012          31  67  14     0  82.6   5.8    22.2   3.1     7
# 6    07    06  2012          33  54  13     0  88.2   9.9    30.5   6.4  10.9
# 7    08    06  2012          30  73  15     0  86.6  12.1    38.3   5.6  13.5
# 8    09    06  2012          25  88  13   0.2  52.9   7.9    38.8   0.4  10.5
# 9    10    06  2012          28  79  12     0  73.2   9.5    46.3   1.3  12.6
# 10   11    06  2012          31  65  14     0  84.5  12.5    54.3     4  15.8
# ...

# %%
#creating new column 'region'
data.loc[0:121, 'Region'] = 'bejaia'
data.loc[124:246, 'Region'] = 'Sidi-Bel Abbes Region Dataset'

# %%
data.reset_index(drop=True)
# Out:
#     day month  year Temperature  RH  Ws Rain   FFMC   DMC      DC   ISI   BUI  \
# 0    01    06  2012          29  57  18     0  65.7   3.4     7.6   1.3   3.4
# 1    02    06  2012          29  61  13   1.3  64.4   4.1     7.6     1   3.9
# 2    03    06  2012          26  82  22  13.1  47.1   2.5     7.1   0.3   2.7
# 3    04    06  2012          25  89  13   2.5  28.6   1.3     6.9     0   1.7
# 4    05    06  2012          27  77  16     0  64.8     3    14.2   1.2   3.9
# 5    06    06  2012          31  67  14     0  82.6   5.8    22.2   3.1     7
# 6    07    06  2012          33  54  13     0  88.2   9.9    30.5   6.4  10.9
# 7    08    06  2012          30  73  15     0  86.6  12.1    38.3   5.6  13.5
# 8    09    06  2012          25  88  13   0.2  52.9   7.9    38.8   0.4  10.5
# 9    10    06  2012          28  79  12     0  73.2   9.5    46.3   1.3  12.6
# 10   11    06  2012          31  65  14     0  84.5  12.5    54.3     4  15.8
# ...

# %%
len(data.columns)
# Out:
# 15

# %%
data.columns = [feature.strip() for feature in data.columns]

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   day          244 non-null    object
#  1   month        244 non-null    object
#  2   year         244 non-null    object
#  3   Temperature  244 non-null    object
#  4   RH           244 non-null    object
#  5   Ws           244 non-null    object
#  6   Rain         244 non-null    object
#  7   FFMC         244 non-null    object
#  8   DMC          244 non-null    object
#  9   DC           244 non-null    object
#  10  ISI          244 non-null    object
#  11  BUI          244 non-null    object
#  12  FWI          244 non-null    object
#  13  Classes      243 non-null    object
#  14  Region       244 non-null    object
# dtypes: object(15)
# memory usage: 38.6+ KB

# %%
#combning the columns day, month and year to form a new column 'date'
data['date'] = pd.to_datetime(data[['day', 'month', 'year']])

# %%
data.columns
# Out:
# Index(['day', 'month', 'year', 'Temperature', 'RH', 'Ws', 'Rain', 'FFMC',
#        'DMC', 'DC', 'ISI', 'BUI', 'FWI', 'Classes', 'Region', 'date'],
#       dtype='object')

# %%
data.drop(['day', 'month', 'year'], axis=1, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    object
#  1   RH           244 non-null    object
#  2   Ws           244 non-null    object
#  3   Rain         244 non-null    object
#  4   FFMC         244 non-null    object
#  5   DMC          244 non-null    object
#  6   DC           244 non-null    object
#  7   ISI          244 non-null    object
#  8   BUI          244 non-null    object
#  9   FWI          244 non-null    object
#  10  Classes      243 non-null    object
#  11  Region       244 non-null    object
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), object(12)
# memory usage: 34.8+ KB

# %%
data[['Temperature', 'RH', 'Ws']] = data[['Temperature', 'RH', 'Ws']].astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 244 entries, 0 to 245
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  244 non-null    int32
#  1   RH           244 non-null    int32
#  2   Ws           244 non-null    int32
#  3   Rain         244 non-null    object
#  4   FFMC         244 non-null    object
#  5   DMC          244 non-null    object
#  6   DC           244 non-null    object
#  7   ISI          244 non-null    object
#  8   BUI          244 non-null    object
#  9   FWI          244 non-null    object
#  10  Classes      243 non-null    object
#  11  Region       244 non-null    object
#  12  date         244 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), int32(3), object(9)
# memory usage: 31.9+ KB

# %%
data[data.DC=='14.6 9']
# Out:
#      Temperature  RH  Ws Rain  FFMC   DMC      DC   ISI   BUI      FWI  \
# 167           37  37  18  0.2  88.9  12.9  14.6 9  12.5  10.4  fire
#
#     Classes                         Region       date
# 167     NaN  Sidi-Bel Abbes Region Dataset 2012-07-14

# %%
data.drop(index=[167], inplace=True)

# %%
data
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  \
# 0             29  57  18     0  65.7   3.4    7.6   1.3   3.4   0.5
# 1             29  61  13   1.3  64.4   4.1    7.6     1   3.9   0.4
# 2             26  82  22  13.1  47.1   2.5    7.1   0.3   2.7   0.1
# 3             25  89  13   2.5  28.6   1.3    6.9     0   1.7     0
# 4             27  77  16     0  64.8     3   14.2   1.2   3.9   0.5
# 5             31  67  14     0  82.6   5.8   22.2   3.1     7   2.5
# 6             33  54  13     0  88.2   9.9   30.5   6.4  10.9   7.2
# 7             30  73  15     0  86.6  12.1   38.3   5.6  13.5   7.1
# 8             25  88  13   0.2  52.9   7.9   38.8   0.4  10.5   0.3
# 9             28  79  12     0  73.2   9.5   46.3   1.3  12.6   0.9
# 10            31  65  14     0  84.5  12.5   54.3     4  15.8   5.6
# 11            26  81  19     0    84  13.8   61.4   4.8  17.7  7.1
# 12            27  84  21   1.2    50   6.7     17   0.5   6.7   0.2
# ...

# %%
data.reset_index(drop=True)
# Out:
#      Temperature  RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  \
# 0             29  57  18     0  65.7   3.4    7.6   1.3   3.4   0.5
# 1             29  61  13   1.3  64.4   4.1    7.6     1   3.9   0.4
# 2             26  82  22  13.1  47.1   2.5    7.1   0.3   2.7   0.1
# 3             25  89  13   2.5  28.6   1.3    6.9     0   1.7     0
# 4             27  77  16     0  64.8     3   14.2   1.2   3.9   0.5
# 5             31  67  14     0  82.6   5.8   22.2   3.1     7   2.5
# 6             33  54  13     0  88.2   9.9   30.5   6.4  10.9   7.2
# 7             30  73  15     0  86.6  12.1   38.3   5.6  13.5   7.1
# 8             25  88  13   0.2  52.9   7.9   38.8   0.4  10.5   0.3
# 9             28  79  12     0  73.2   9.5   46.3   1.3  12.6   0.9
# 10            31  65  14     0  84.5  12.5   54.3     4  15.8   5.6
# 11            26  81  19     0    84  13.8   61.4   4.8  17.7  7.1
# 12            27  84  21   1.2    50   6.7     17   0.5   6.7   0.2
# ...

# %%
data.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'Region', 'date'],
#       dtype='object')

# %%
data[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']] = data[['Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']].astype('float')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int32
#  1   RH           243 non-null    int32
#  2   Ws           243 non-null    int32
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    object
#  11  Region       243 non-null    object
#  12  date         243 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int32(3), object(2)
# memory usage: 23.7+ KB

# %%
data['Classes'] = data.Classes.str.strip()

# %%
data.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'Region', 'date'],
#       dtype='object')

# %%
data.columns
# Out:
# Index(['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI',
#        'FWI', 'Classes', 'Region', 'date'],
#       dtype='object')

# %%
data.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# date           0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label = LabelEncoder()

# %%
data['Classes'] = label.fit_transform(data.Classes)

# %%
label.classes_
# Out:
# array(['fire', 'not fire'], dtype=object)

# %%
data['Region'] = label.fit_transform(data.Region)

# %%
label.classes_
# Out:
# array(['Sidi-Bel Abbes Region Dataset', 'bejaia'], dtype=object)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 243 entries, 0 to 245
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  243 non-null    int32
#  1   RH           243 non-null    int32
#  2   Ws           243 non-null    int32
#  3   Rain         243 non-null    float64
#  4   FFMC         243 non-null    float64
#  5   DMC          243 non-null    float64
#  6   DC           243 non-null    float64
#  7   ISI          243 non-null    float64
#  8   BUI          243 non-null    float64
#  9   FWI          243 non-null    float64
#  10  Classes      243 non-null    int32
#  11  Region       243 non-null    int32
#  12  date         243 non-null    datetime64[ns]
# dtypes: datetime64[ns](1), float64(7), int32(5)
# memory usage: 21.8 KB

# %%
[feature for feature in data.columns if data[feature].nunique()<=3]
# Out:
# ['Classes', 'Region']

# %%
numerical_feature = ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI','FWI']

# %%
numerical_feature
# Out:
# ['Temperature', 'RH', 'Ws', 'Rain', 'FFMC', 'DMC', 'DC', 'ISI', 'BUI', 'FWI']

# %%
plt.figure(figsize=(20,20))
plt.suptitle('distribution plot of all the numerical variables', fontsize=20, fontweight='bold')

for i in range(0, len(numerical_feature)):
    plt.subplot(5,4,i+1)
    sns.kdeplot(data[numerical_feature[i]], shade=True, color='r')
    plt.tight_layout()

# %%
sns.countplot(data['Classes'])
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Classes', ylabel='count'>

# %%
#distribution of temperature feature
sns.distplot(data['Temperature'], bins=30, color='y')
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Temperature', ylabel='Density'>

# %%
sns.barplot(x='Temperature', y='Rain', data=data)
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Rain'>

# %% [markdown]
# when the temperature is 22 there is a maximum probability of rain to occur

# %%
sns.barplot(x=data.Region, y=data.Classes)
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Classes'>

# %% [markdown]
# 0 of classes represent fire,
# 1 of classes represnt not fire,
# 0 of region represent seibei dataset,
# 1 of region represent bejaiau.
#
# so seibei region is more prone to fire

# %% [markdown]
# # correlation of features

# %%
data[numerical_feature].corr()
# Out:
#              Temperature        RH        Ws      Rain      FFMC       DMC  \
# Temperature     1.000000 -0.651400 -0.284510 -0.326492  0.676568  0.485687
# RH             -0.651400  1.000000  0.244048  0.222356 -0.644873 -0.408519
# Ws             -0.284510  0.244048  1.000000  0.171506 -0.166548 -0.000721
# Rain           -0.326492  0.222356  0.171506  1.000000 -0.543906 -0.288773
# FFMC            0.676568 -0.644873 -0.166548 -0.543906  1.000000  0.603608
# DMC             0.485687 -0.408519 -0.000721 -0.288773  0.603608  1.000000
# DC              0.376284 -0.226941  0.079135 -0.298023  0.507397  0.875925
# ISI             0.603871 -0.686667  0.008532 -0.347484  0.740007  0.680454
# BUI             0.459789 -0.353841  0.031438 -0.299852  0.592011  0.982248
# FWI             0.566670 -0.580957  0.032368 -0.324422  0.691132  0.875864
#
#                    DC       ISI       BUI       FWI
# Temperature  0.376284  0.603871  0.459789  0.566670
# ...

# %%
plt.figure(figsize=(7,5))
sns.heatmap(data[numerical_feature].corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(8,8))
sns.lineplot(x=data['Temperature'], y=data['date'], data=data, color='r')
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='date'>

# %%
sns.regplot(x=data['Temperature'], y=data['FFMC'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='FFMC'>

# %%
sns.regplot(x=data['Temperature'], y=data['RH'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='RH'>

# %%
sns.regplot(x=data['Temperature'], y=data['ISI'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='ISI'>

# %% [markdown]
# The target variable Temperature is highly positively correlated with 'FFMC' and 'ISI'
#
# Highly negatively correlated with 'RH'

# %%
#plotting box plot to see the outliers present in the dataset

plt.figure(figsize=(20,20))
plt.suptitle('box plot of different numerical variables')

for i in range(0, len(numerical_feature)):
    plt.subplot(5,4,i+1)
    sns.boxplot(data[numerical_feature[i]])
    plt.tight_layout()
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
data.isnull().sum()
# Out:
# Temperature    0
# RH             0
# Ws             0
# Rain           0
# FFMC           0
# DMC            0
# DC             0
# ISI            0
# BUI            0
# FWI            0
# Classes        0
# Region         0
# date           0
# dtype: int64

# %%
#boxplot of temperature vs rain

sns.boxplot(x=data['Temperature'], y=data['Rain'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='Rain'>

# %%
#boxplot of FMCC vs Temperature

sns.boxplot(x=data['Temperature'], y=data['FFMC'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='FFMC'>

# %%
#boxplot of ISI vs temperature

sns.boxplot(x=data['Temperature'], y=data['ISI'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='ISI'>

# %%
#boxplot of region vs temperature

sns.boxplot(y=data['Temperature'], x=data['Region'])
# Out:
# <AxesSubplot:xlabel='Region', ylabel='Temperature'>

# %%
#boxplot of BUI vs temperature

sns.boxplot(x=data['Temperature'], y=data['BUI'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='BUI'>

# %%
#boxplot of FWI vs temperature

sns.boxplot(x=data['Temperature'], y=data['FWI'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='FWI'>

# %%
#boxplot of DMC vs temperature

sns.boxplot(y=data['DMC'], x=data['Temperature'])
# Out:
# <AxesSubplot:xlabel='Temperature', ylabel='DMC'>

# %%
x = data.drop(['date', 'Classes', 'Temperature'], axis=1)

# %%
y = data.Temperature

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test= train_test_split(x, y, test_size=0.33, random_state=10)

# %%
x_train
# Out:
#      RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  Region
# 25   64  18   0.0  86.8  17.8   71.8   6.7  21.6  10.6       1
# 121  78  14   1.4  45.0   1.9    7.5   0.2   2.4   0.1       1
# 176  71  17   0.0  87.3  46.6   99.0   6.9  46.5  16.3       0
# 72   51  13   0.3  81.3  15.6   75.1   2.5  20.7   4.2       1
# 188  35  15   0.0  93.8  23.0   42.7  15.7  22.9  20.9       0
# 233  33  13   0.1  90.6  25.8   77.8   9.0  28.2  15.4       0
# 170  81  17   0.0  84.6  21.1   42.3   4.7  20.9   7.7       0
# 206  53  14   0.0  89.5  41.1  127.5   8.0  45.5  18.1       0
# 230  51  13   0.0  88.7  16.0   50.2   6.9  17.8   9.8       0
# 221  71  14   6.5  64.5   3.3    9.1   1.0   3.5   0.4       0
# 161  47  18   6.0  80.8   9.8    9.7   3.1   9.4   3.0       0
# 43   61  13   0.6  73.9   7.8   22.9   1.4   8.4   0.8       1
# 175  48  18   0.0  91.5  44.2   90.1  13.2  44.0  25.4       0
# 21   67  17   0.1  79.1   7.0   39.5   2.4   9.7   2.3       1
# ...

# %%
x_test
# Out:
#      RH  Ws  Rain  FFMC   DMC     DC   ISI   BUI   FWI  Region
# 46   70  14   0.0  82.8   9.4   34.1   3.2  11.1   3.6       1
# 228  49  19   0.0  88.6  11.5   33.4   9.1  12.4  10.3       0
# 183  56  16   0.0  88.9  23.8   57.1   8.2  23.8  13.2       0
# 116  81  21   5.8  48.6   3.0    7.7   0.4   3.0   0.1       1
# 126  80  14   2.0  48.7   2.2    7.6   0.3   2.6   0.1       0
# 172  58  16   0.0  88.1  27.8   61.1   7.3  27.7  13.0       0
# 68   60  18   0.3  77.1  11.3   47.0   2.2  14.1   2.6       1
# 173  50  16   0.0  89.9  32.7   71.0   9.5  32.6  17.3       0
# 148  70  16   0.0  86.0  12.8   25.6   5.4  12.7   6.7       0
# 119  47  14   0.7  77.5   7.1    8.8   1.8   6.8   0.9       1
# 179  58  10   0.2  78.3  10.8   19.7   1.6  10.7   1.0       0
# 35   63  14   0.0  87.0  10.9   37.0   5.6  12.5   6.8       1
# 197  34  16   0.2  88.3  16.9   45.1   7.5  17.5  10.5       0
# 59   79  15   0.0  85.4  28.5  136.0   4.7  37.4  10.7       1
# ...

# %%
y_train
# Out:
# 25     31
# 121    25
# 176    31
# 72     35
# 188    38
# 233    36
# 170    32
# 206    37
# 230    32
# 221    34
# 161    35
# 43     34
# 175    32
# 21     31
# 156    34
# 37     33
# 205    36
# 75     36
# 194    39
# 48     35
# 193    39
# 222    31
# 186    40
# 196    39
# 99     30
# 95     29
# 191    34
# 67     32
# 66     32
# 174    36
# 22     32
# 38     32
# 241    30
# 232    34
# 101    33
# 199    35
# 243    27
# 215    30
# 131    28
# 218    28
# 204    36
# 114    32
# 154    28
# 90     35
# 41     31
# 80     35
# 105    22
# 81     36
# 134    31
# 110    29
# 53     28
# 17     31
# 157    34
# 51     28
# 14     28
# 216    29
# 82     36
# 84     34
# 227    31
# 29     33
# 3      25
# 23     32
# 130    35
# 45     28
# 229    28
# 97     29
# 198    37
# 42     34
# 165    36
# 79     35
# 237    33
# 12     27
# 112    31
# 11     26
# 192    37
# 85     35
# 136    30
# 145    33
# 168    34
# 185    38
# 104    25
# 34     33
# 108    31
# ...

# %%
y_test
# Out:
# 46     29
# 228    29
# 183    36
# 116    26
# 126    29
# 172    34
# 68     32
# 173    36
# 148    34
# 119    32
# 179    35
# 35     32
# 197    35
# 59     31
# 213    35
# 26     34
# 120    26
# 187    39
# 10     31
# 91     28
# 76     36
# 190    30
# 60     35
# 178    39
# 98     31
# 149    36
# 117    31
# 132    27
# 63     35
# 239    26
# 6      33
# 144    32
# 162    36
# 24     31
# 87     33
# 19     30
# 163    34
# 146    33
# 55     36
# 61     36
# 184    37
# 133    30
# 70     35
# 234    29
# 69     35
# 202    37
# 164    34
# 56     36
# 217    28
# 20     30
# 47     31
# 201    42
# 5      31
# 109    32
# 106    24
# 208    35
# 150    36
# 235    34
# 138    28
# 49     33
# 58     32
# 1      29
# 2      26
# 151    37
# 211    36
# 103    29
# 52     27
# 140    31
# 207    36
# 32     32
# 111    28
# 7      30
# 245    24
# 39     33
# 83     36
# 171    33
# 129    35
# 244    24
# 210    33
# 102    30
# 78     36
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
def standardize(data):
    for feature in data.columns:
        scaler = StandardScaler()
        data[feature] = scaler.fit_transform(data[feature].array.reshape(-1,1))

# %%
standardize(x_train)

# %%
x_train
# Out:
#            RH        Ws      Rain      FFMC       DMC        DC       ISI  \
# 25   0.068359  0.896735 -0.424065  0.639043  0.305846  0.490280  0.480862
# 121  0.996728 -0.581851  0.404341 -2.124443 -1.042891 -0.863048 -1.071400
# 176  0.532543  0.527088 -0.424065  0.672099  2.748840  1.062762  0.528624
# 72  -0.793698 -0.951497 -0.246549  0.275426  0.119228  0.559736 -0.522138
# 188 -1.854692 -0.212204 -0.424065  1.101827  0.746942 -0.122190  2.630148
# 233 -1.987316 -0.951497 -0.364893  0.890269  0.984455  0.616563  1.030124
# 170  1.195664  0.527088 -0.424065  0.493596  0.585772 -0.130609  0.003243
# 206 -0.661074 -0.581851 -0.424065  0.817545  2.282296  1.662604  0.791315
# 230 -0.793698 -0.951497 -0.424065  0.764656  0.153158  0.035663  0.528624
# 221  0.532543 -0.581851  3.422103 -0.835257 -0.924134 -0.829373 -0.880352
# 161 -1.058947  0.896735  3.126244  0.242370 -0.372764 -0.816744 -0.378852
# 43  -0.130578 -0.951497 -0.069034 -0.213803 -0.542416 -0.538923 -0.784828
# ...

# %%
standardize(x_test)

# %%
x_test
# Out:
#            RH        Ws      Rain      FFMC       DMC        DC       ISI  \
# 46   0.699425 -0.445976 -0.341841  0.284765 -0.466732 -0.360780 -0.407613
# 228 -0.797081  1.226435 -0.341841  0.751232 -0.309987 -0.375478  1.046106
# 183 -0.298245  0.222988 -0.341841  0.775359  0.608088  0.122178  0.824352
# 116  1.483309  1.895400  1.975574 -2.465779 -0.944430 -0.915131 -1.097514
# 126  1.412047 -0.445976  0.457268 -2.457737 -1.004142 -0.917231 -1.122153
# 172 -0.155721  0.222988 -0.341841  0.711019  0.906649  0.206171  0.602599
# 68  -0.013197  0.891953 -0.221975 -0.173659 -0.324915 -0.089903 -0.654007
# 173 -0.725819  0.222988 -0.341841  0.855785  1.272386  0.414053  1.144663
# 148  0.699425  0.222988 -0.341841  0.542126 -0.212955 -0.539264  0.134452
# 119 -0.939605 -0.445976 -0.062153 -0.141489 -0.638405 -0.892033 -0.752564
# 179 -0.155721 -1.783906 -0.261930 -0.077149 -0.362236 -0.663153 -0.801842
# 35   0.200590 -0.445976 -0.341841  0.622551 -0.354772 -0.299885  0.183730
# ...

# %% [markdown]
# # Linear Regression Model Fitting

# %%
from sklearn.linear_model import LinearRegression

# %%
linear = LinearRegression()

# %%
#fitting x_train and y_train 
linear.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#co-efficient of x_train and y_train
linear.coef_
# Out:
# array([-1.45732761, -0.717256  , -0.25440877,  0.93258152, -0.086711  ,
#         0.37465144,  0.27747737,  0.4158806 , -0.43324618, -0.21483906])

# %%
#intercept of x_train and y_train
linear.intercept_
# Out:
# 32.074074074074076

# %%
#predicting the target variable by using x_test
y_pred = linear.predict(x_test)
y_pred
# Out:
# array([31.34184413, 33.23704183, 33.45463181, 24.97601246, 27.56937519,
#        33.25081935, 31.12266452, 34.31132591, 31.46619296, 33.01178362,
#        33.52118093, 32.42253845, 35.55054907, 31.48237227, 33.78608935,
#        33.08493666, 26.58981934, 35.88345594, 32.20226915, 24.37557203,
#        31.6400222 , 31.99746522, 32.72181912, 32.66507005, 29.38926897,
#        32.53532592, 33.46608463, 31.40661227, 31.30426435, 34.01480785,
#        33.63034865, 33.4383015 , 33.88408107, 32.32556649, 30.53067481,
#        27.89448983, 32.24767597, 31.44383308, 33.01818923, 33.36916195,
#        33.93893167, 34.97840475, 33.70094914, 36.95453494, 32.3478106 ,
#        36.61198226, 31.83841793, 35.1687762 , 30.10613871, 30.33776751,
#        31.84690887, 39.19725259, 31.50793767, 34.75129928, 26.54071813,
#        36.71937682, 33.69283782, 33.6385277 , 28.03457233, 31.80857687,
#        32.06437609, 30.65638001, 23.76101348, 36.40143509, 35.61277919,
# ...

# %%
#finding the residuals of the dataset 
residual = y_test-y_pred
residual
# Out:
# 46    -2.341844
# 228   -4.237042
# 183    2.545368
# 116    1.023988
# 126    1.430625
# 172    0.749181
# 68     0.877335
# 173    1.688674
# 148    2.533807
# 119   -1.011784
# 179    1.478819
# 35    -0.422538
# 197   -0.550549
# 59    -0.482372
# 213    1.213911
# 26     0.915063
# 120   -0.589819
# 187    3.116544
# 10    -1.202269
# 91     3.624428
# 76     4.359978
# 190   -1.997465
# 60     2.278181
# 178    6.334930
# 98     1.610731
# 149    3.464674
# 117   -2.466085
# 132   -4.406612
# 63     3.695736
# 239   -8.014808
# 6     -0.630349
# 144   -1.438301
# 162    2.115919
# 24    -1.325566
# 87     2.469325
# 19     2.105510
# 163    1.752324
# 146    1.556167
# 55     2.981811
# 61     2.630838
# 184    3.061068
# 133   -4.978405
# 70     1.299051
# 234   -7.954535
# 69     2.652189
# 202    0.388018
# 164    2.161582
# 56     0.831224
# 217   -2.106139
# 20    -0.337768
# 47    -0.846909
# 201    2.802747
# 5     -0.507938
# 109   -2.751299
# 106   -2.540718
# ...

# %%
#to check the assumptions of linear model
#y_test and y_pred should be normally distributed

sns.regplot(y_test, y_pred)
# Out:
# C:\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Temperature'>

# %%
from scipy.stats import probplot

# %%
#2nd assumption
#residuals are normally distributed

plt.figure(figsize=(7,5))

plt.subplot(1,2,1)
plt.title('distribution of residuals')
sns.distplot(residual)

plt.subplot(1,2,2)
plt.title('QQ-plot of residuals')
probplot(residual, plot=plt, fit=True, dist='norm')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3rd assumption
#errors to be spread randomly

sns.scatterplot(x=residual, y=y_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %% [markdown]
# # performance metrics

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.metrics import median_absolute_error

# %%
print (mean_squared_error(y_test, y_pred))
print (mean_absolute_error(y_test, y_pred))
print (np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# 7.98883936429833
# 2.1988401823567933
# 2.8264534958669194

# %%
#r2 score of the model 
from sklearn.metrics import r2_score

# %%
#r2 score 
r2_score = r2_score(y_test, y_pred)
r2_score
# Out:
# 0.42289730611775134

# %%
#adjusted r2 score
#Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)] formula
adj_R2 = 1 - (1-r2_score)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
adj_R2
# Out:
# 0.340454064134573

# %% [markdown]
# # ridge regression

# %%
from sklearn.linear_model import Ridge

# %%
ridge = Ridge()

# %%
#fitting ridge model on training dataset
ridge.fit(x_train, y_train)
# Out:
# Ridge()

# %%
#co-efficient of ridge model
ridge.coef_
# Out:
# array([-1.43943941, -0.7160425 , -0.25512583,  0.93891733,  0.00628512,
#         0.39583232,  0.21860463,  0.25319759, -0.32843448, -0.2115963 ])

# %%
#intercept of ridge model
ridge.intercept_
# Out:
# 32.074074074074076

# %%
#predicting the testset target variable by applying x_test
yr_pred = ridge.predict(x_test)
yr_pred
# Out:
# array([31.35200708, 33.2233459 , 33.4723347 , 25.00978537, 27.59389811,
#        33.26803794, 31.10600031, 34.33002367, 31.48436513, 32.99348692,
#        33.50157615, 32.43047945, 35.52925278, 31.47028082, 33.72288153,
#        33.08905016, 26.62157903, 35.84632644, 32.20139458, 24.38888604,
#        31.62288213, 31.9701027 , 32.71543814, 32.65027662, 29.40014494,
#        32.54786581, 33.46081433, 31.39992031, 31.31112467, 33.9776639 ,
#        33.62840658, 33.43293674, 33.85837611, 32.32661604, 30.48057093,
#        27.91748378, 32.22712006, 31.43517846, 33.0128607 , 33.35384225,
#        33.95779494, 34.95943363, 33.70222166, 36.88993911, 32.35188184,
#        36.63527536, 31.82537427, 35.15386586, 30.1084888 , 30.35394841,
#        31.85667683, 39.19279366, 31.51530464, 34.73978994, 26.57724967,
#        36.73313201, 33.7022157 , 33.58684847, 28.06447738, 31.79687977,
#        32.05797886, 30.66384725, 23.79459674, 36.40006253, 35.63875235,
# ...

# %%
residualr = y_test-yr_pred
residualr
# Out:
# 46    -2.352007
# 228   -4.223346
# 183    2.527665
# 116    0.990215
# 126    1.406102
# 172    0.731962
# 68     0.894000
# 173    1.669976
# 148    2.515635
# 119   -0.993487
# 179    1.498424
# 35    -0.430479
# 197   -0.529253
# 59    -0.470281
# 213    1.277118
# 26     0.910950
# 120   -0.621579
# 187    3.153674
# 10    -1.201395
# 91     3.611114
# 76     4.377118
# 190   -1.970103
# 60     2.284562
# 178    6.349723
# 98     1.599855
# 149    3.452134
# 117   -2.460814
# 132   -4.399920
# 63     3.688875
# 239   -7.977664
# 6     -0.628407
# 144   -1.432937
# 162    2.141624
# 24    -1.326616
# 87     2.519429
# 19     2.082516
# 163    1.772880
# 146    1.564822
# 55     2.987139
# 61     2.646158
# 184    3.042205
# 133   -4.959434
# 70     1.297778
# 234   -7.889939
# 69     2.648118
# 202    0.364725
# 164    2.174626
# 56     0.846134
# 217   -2.108489
# 20    -0.353948
# 47    -0.856677
# 201    2.807206
# 5     -0.515305
# 109   -2.739790
# 106   -2.577250
# ...

# %%
#checking the assumptions of the ridge regression
sns.regplot(x=y_test, y=yr_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
#checking the 2nd assumption
#residuals are normally distributed

plt.figure(figsize=(7,5))

plt.subplot(1,2,1)
plt.title('distribution of residuals')
sns.distplot(residualr)

plt.subplot(1,2,2)
plt.title('QQ-plot of residuals')
probplot(residualr, plot=plt, fit=True, dist='norm')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3rd assumption
#errors to be spread randomly

sns.scatterplot(x=residualr, y=yr_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
print(mean_squared_error(y_test, yr_pred))
print(mean_absolute_error(y_test, yr_pred))
print(np.sqrt(mean_squared_error(y_test, yr_pred)))
# Out:
# 7.964546354222974
# 2.1979306422895113
# 2.822152787186224

# %%
#finding out the r2 value of this model
from sklearn.metrics import r2_score
ridge_r2 = r2_score(y_test, yr_pred)
ridge_r2
# Out:
# 0.42465219952813205

# %%
#Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)] formula
adj_R2 = 1 - (1-ridge_r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
adj_R2
# Out:
# 0.34245965660357947

# %% [markdown]
# # Lasso Regression

# %%
from sklearn.linear_model import Lasso

# %%
lass = Lasso()

# %%
#testing the model on train dataset 
lass.fit(x_train, y_train)
# Out:
# Lasso()

# %%
#co-efficient and intercept 
print(lass.coef_)
print(lass.intercept_)
# Out:
# [-0.88423537 -0.         -0.          0.88313134  0.          0.
#   0.          0.          0.         -0.        ]
# 32.074074074074076

# %%
#predicting the test dataset
lass_pred = lass.predict(x_test)
print(lass_pred)
# Out:
# [31.70710255 33.44231728 33.02253728 28.58487256 28.65498772 32.83969133
#  31.93237934 33.47163864 31.93438601 32.77995286 32.14363573 32.44649991
#  34.36619763 31.32465746 32.59364801 33.21867753 28.56265381 34.81275102
#  32.14290962 28.92488683 32.08954765 31.84168247 32.39769258 31.44594309
#  30.70654573 32.56633332 32.65848241 32.06641797 31.70782866 31.50330525
#  33.09884412 32.89377941 33.37292823 32.36217954 31.10010678 29.44337722
#  32.52790268 31.78941625 33.23288274 32.99831186 33.11396026 34.0032385
#  33.08554983 33.61259505 32.72696053 34.60331648 32.02106953 33.62607416
#  31.37054718 31.07515524 32.01779546 35.54322391 31.88193497 33.49913814
#  28.25906351 34.38404656 33.09975505 32.22886703 29.31043434 31.92272876
#  31.78796403 30.96733556 28.41532089 34.47546954 33.29771715 29.73476897
#  30.92217194 30.30697782 34.00506036 29.92981347 30.895953   31.78796403
#  30.98427356 30.61949257 33.25419057 32.06751371 32.77922675 32.49512242
# ...

# %%
lass_residual = y_test-lass_pred
lass_residual
# Out:
# 46    -2.707103
# 228   -4.442317
# 183    2.977463
# 116   -2.584873
# 126    0.345012
# 172    1.160309
# 68     0.067621
# 173    2.528361
# 148    2.065614
# 119   -0.779953
# 179    2.856364
# 35    -0.446500
# 197    0.633802
# 59    -0.324657
# 213    2.406352
# 26     0.781322
# 120   -2.562654
# 187    4.187249
# 10    -1.142910
# 91    -0.924887
# 76     3.910452
# 190   -1.841682
# 60     2.602307
# 178    7.554057
# 98     0.293454
# 149    3.433667
# 117   -1.658482
# 132   -5.066418
# 63     3.292171
# 239   -5.503305
# 6     -0.098844
# 144   -0.893779
# 162    2.627072
# 24    -1.362180
# 87     1.899893
# 19     0.556623
# 163    1.472097
# 146    1.210584
# 55     2.767117
# 61     3.001688
# 184    3.886040
# 133   -4.003239
# 70     1.914450
# 234   -4.612595
# 69     2.273039
# 202    2.396684
# 164    1.978930
# 56     2.373926
# 217   -3.370547
# 20    -1.075155
# 47    -1.017795
# 201    6.456776
# 5     -0.881935
# 109   -1.499138
# 106   -4.259064
# ...

# %%
#checking the assumptions of the ridge regression
sns.regplot(x=y_test, y=lass_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
#checking the 2nd assumption
#residuals are normally distributed

plt.figure(figsize=(7,5))

plt.subplot(1,2,1)
plt.title('distribution of residuals')
sns.distplot(lass_residual)

plt.subplot(1,2,2)
plt.title('QQ-plot of residuals')
probplot(lass_residual, plot=plt, fit=True, dist='norm')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3rd assumption
#errors to be spread randomly

sns.scatterplot(x=lass_residual, y=lass_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
#r2 score
lass_r2 = r2_score(y_test, lass_pred)
lass_r2
# Out:
# 0.40048155588545564

# %%
#Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)] formula
adj_R2 = 1 - (1-lass_r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
adj_R2
# Out:
# 0.31483606386909213

# %% [markdown]
# # ElasticNet model

# %%
from sklearn.linear_model import ElasticNet

# %%
elastic = ElasticNet()

# %%
elastic.fit(x_train, y_train)
# Out:
# ElasticNet()

# %%
#printing co-efficient and intercepts
print(elastic.coef_)
print(elastic.intercept_)
# Out:
# [-0.77155493 -0.27327033 -0.02945645  0.70980198  0.11177449  0.
#   0.20914599  0.04593431  0.12829249 -0.        ]
# 32.074074074074076

# %%
elastic_pred = elastic.predict(x_test)

# %%
#residuals 
elastic_residual = y_test - elastic_pred
elastic_residual
# Out:
# 46    -2.648267
# 228   -4.112604
# 183    2.841949
# 116   -2.102898
# 126    0.164917
# 172    1.001864
# 68     0.539312
# 173    2.219270
# 148    2.154279
# 119   -0.453144
# 179    2.700279
# 35    -0.465976
# 197    0.826329
# 59    -0.644722
# 213    2.679199
# 26     0.785195
# 120   -2.587488
# 187    3.904609
# 10    -1.134644
# 91    -0.328522
# 76     4.346009
# 190   -1.656941
# 60     2.380171
# 178    7.228457
# 98     0.645085
# 149    3.440952
# 117   -1.645792
# 132   -4.532695
# 63     3.495728
# 239   -6.120020
# 6     -0.155253
# 144   -0.763103
# 162    3.024191
# 24    -1.379294
# 87     1.849793
# 19     0.641681
# 163    1.958922
# 146    1.592108
# 55     2.862423
# 61     3.369790
# 184    3.594817
# 133   -3.939924
# 70     1.720901
# 234   -5.044032
# 69     2.398388
# 202    1.550848
# 164    2.325078
# 56     1.983793
# 217   -2.749828
# 20    -1.017555
# 47    -1.050299
# 201    5.398907
# 5     -0.735913
# 109   -1.710702
# 106   -4.414280
# ...

# %%
#checking the assumptions of the ridge regression
sns.regplot(x=y_test, y=elastic_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
#checking the 2nd assumption
#residuals are normally distributed

plt.figure(figsize=(7,5))

plt.subplot(1,2,1)
plt.title('distribution of residuals')
sns.distplot(elastic_residual)

plt.subplot(1,2,2)
plt.title('QQ-plot of residuals')
probplot(elastic_residual, plot=plt, fit=True, dist='norm')
plt.show()
# Out:
# C:\anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
#3rd assumption
#errors to be spread randomly

sns.scatterplot(x=elastic_residual, y=lass_pred)
# Out:
# <AxesSubplot:xlabel='Temperature'>

# %%
#r2 score
elastic_r2 = r2_score(y_test, elastic_pred)
elastic_r2
# Out:
# 0.442197092028601

# %%
#Adjusted R2 = 1 – [(1-R2)*(n-1)/(n-k-1)] formula
adj_R2 = 1 - (1-elastic_r2)*(len(y_test)-1)/(len(y_test)-x_test.shape[1]-1)
adj_R2
# Out:
# 0.3625109623184012
